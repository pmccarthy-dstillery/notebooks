# %%
Assuming URL slugs have some semantic content, can we harvest that?

# %%
import fasttext
import os
import pandas as pd
import re
import sys
from typing import List, Tuple


import tldextract

# %%
FILES = {
    'wiki.en.bin':                             '/home/pmccarthy/projects/audiencefinder/data/wiki.en.bin',          
}

# %%
JOBNAME = 'MLE-4610 - Full URLs in Fasttext'

# %%
# os.environ['SPARK_HOME'] = '/home/pmccarthy/nas/opt/spark'
# os.environ['PYSPARK_PYTHON'] = '/usr/bin/python3.6'
# os.environ['PYSPARK_PYTHON'] = './ip_env/ip_env/bin/python'

os.environ['SPARK_HOME'] = '/home/pmccarthy/nas/opt/spark-2.4.7-bin-hadoop2.7'
os.environ['PYSPARK_PYTHON'] = './py37minimal_env/py37minimal/bin/python'

dist_archives = 'hdfs:///user/pmccarthy/conda/py37minimal.zip#py37minimal_env'

# dist_archives = 'hdfs:///user/pmccarthy/conda/ip_env.zip#ip_env'

sys.path.insert(0,os.path.join(os.environ['SPARK_HOME'],'python','lib','py4j-src.zip'))
sys.path.append(os.path.join(os.environ['SPARK_HOME'],'python'))

import pyspark
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql import types as T
from pyspark.sql import window as W


spark = (SparkSession
         .builder
         .enableHiveSupport()
         .appName(f"{os.uname()[1].split('.')[0]}: {JOBNAME}")
         .config('spark.master','yarn')
         .config('spark.yarn.deployMode','client')
         .config('spark.executor.cores',1)
         .config('spark.executor.memory','2g')
         .config('spark.driver.memory','5g')
         .config('spark.dynamicAllocation.maxExecutors',1500)
         .config('spark.yarn.dist.archives', dist_archives)
         .config('spark.hadoop.mapreduce.fileoutputcommitter.algorithm.version','2')
         .config('spark.hadoop.parquet.enable.summary-metadata','false')
         .config('spark.sql.parquet.mergeSchema','false')
         .config('spark.sql.parquet.filterPushdown','true')
         .config('spark.sql.hive.metastorePartitionPruning','true')
         .getOrCreate())

# %%
ft_model = fasttext.load_model(FILES['wiki.en.bin'])

# %%
def partitions_to_df(partition_list: List[Tuple[str]]) -> pd.DataFrame:
    # extract column names from first row which looks like    
    #
    # [('offerid=6007/levelid=40/hit_date=20210213',),
    
    first_row_first_tuple = partition_list[0][0]
    
    colnames = [x.split('=')[0] for x in first_row_first_tuple.split('/')]
    
    # keep every other ID, which contain values
    odd_ids = list(range(1,2*len(colnames),2))
    
    df = (
        pd.DataFrame(
            # make all delimiters into '/' and then split on it
            map(lambda x: x[0].replace("=","/").split('/'), partition_list),
        )[odd_ids]
    )
    
    df.columns = colnames
    
    return df

# %%
parts = spark.sql("show partitions stash_dice.content").toPandas()

partitions_df = partitions_to_df(
    [(x,) for x in parts['partition'].tolist()])

# %%
N_LESS_1_DATE = sorted(partitions_df['hit_date_utc'].unique().tolist())[-2]

# %%
some_urls_df = (
    spark.table('stash_dice.content')
    .filter(F.col('hit_date_utc')==N_LESS_1_DATE)
    .select('url_host','url_path')
).show(n=40,truncate=False)
# Out:
# +------------------------+----------------------------------------------------------------------------------------------------------------+
# |url_host                |url_path                                                                                                        |
# +------------------------+----------------------------------------------------------------------------------------------------------------+
# |en.365economist.com     |/30-brilliant-solutions-that-will-make-the-best-of-your-limit                                                   |
# |mail.yahoo.com          |                                                                                                                |
# |www.bostonherald.com    |                                                                                                                |
# |finance.yahoo.com       |                                                                                                                |
# |finance.yahoo.com       |/quote/MRNA                                                                                                     |
# |www.scarymommy.com      |/having-baby-during-pandemic-emotional                                                                          |
# |www.minq.com            |/lifestyle/2563101/people-share-the-time-they-unapologetically-stood-up-to-their-entitled-in-laws               |
# |en.kueez.com            |/50-of-the-most-epic-and-hilarious-sports-bloopers-of-all-tim                                                   |
# |www.minq.com            |/lifestyle/2563101/people-share-the-time-they-unapologetically-stood-up-to-their-entitled-in-laws               |
# |mobile.ghanaweb.com     |/GhanaHomePage/NewsArchive                                                                                      |
# |mobile.ghanaweb.com     |/GhanaHomePage/NewsArchive                                                                                      |
# |www.sparknotes.com      |/lit/flies/section2                                                                                             |
# |mail.yahoo.com          |                                                                                                                |
# |en.365economist.com     |/30-brilliant-solutions-that-will-make-the-best-of-your-limit                                                   |
# |outlook.live.com        |                                                                                                                |
# |brobible.com            |/sports/article/vivian-flores-butterfly-424-catfishing-allegations                                              |
# |www.space.com           |/space-race.html                                                                                                |
# |www.yahoo.com           |                                                                                                                |
# |myhealthgazette.com     |/45-funny-air-travel-facts                                                                                      |
# |medical-news.org        |/30-popular-foods-children-shouldnt-be-fed/12938/10                                                             |
# |www.drivepedia.com      |/trending/finds-mysterious-internet-fb/6                                                                        |
# |www.cbc.ca              |/news/technology/retail-chemicals-report-1.5976620                                                              |
# |en.wackojaco.com        |/40-places-around-the-world-that-are-forbidden-to-travel-to                                                     |
# |weather.com             |/weather/tenday/l/ff548795d9b9049e515ce9e8eee210ad30b0bcbf50339f14198db3910ffb06ce                              |
# |word.tips               |/unscramble/eaofsod                                                                                             |
# |mail.yahoo.com          |                                                                                                                |
# |mail.yahoo.com          |                                                                                                                |
# |www.wsfa.com            |/2021/04/19/killed-injured-sunday-montgomery-shooting                                                           |
# |www.fox23.com           |/news/video-several-teachers-staff-members-resigning-catoosa-public-schools/525e9b3e-2c15-4495-8db2-72b80cb0bedb|
# |www.theprimarymarket.com|/view/brilliant-japanese-design-tpm                                                                             |
# |www.habsetlnh.com       |/Alex-Romanov-sonne-les-cloches-a-Jujhar-Khaira-39233                                                           |
# |clashofclans.fandom.com |/wiki/O.T.T.O                                                                                                   |
# |www.ranker.com          |/list/colonial-mash-v2/mel-judson                                                                               |
# |comicbook.com           |/tv-shows/news/ginny-and-georgia-season-2-netflix-renewed-streaming                                             |
# |finance.yahoo.com       |/quote/DOGE-USD                                                                                                 |
# |mail.yahoo.com          |                                                                                                                |
# |mail.yahoo.com          |                                                                                                                |
# |mail.yahoo.com          |                                                                                                                |
# |www.blackpeoplemeet.com |/v3/profile                                                                                                     |
# |weather.com             |/weather/hourbyhour/l/c44f2773cda02fec98442b446569b1a196b72bcb73ca2acdcf864db6e4c2fc18                          |
# +------------------------+----------------------------------------------------------------------------------------------------------------+
# only showing top 40 rows

# %%
spark.stop()

# %%
paths = """
+------------------------+----------------------------------------------------------------------------------------------------------------+
|url_host                |url_path                                                                                                        |
+------------------------+----------------------------------------------------------------------------------------------------------------+
|en.365economist.com     |/30-brilliant-solutions-that-will-make-the-best-of-your-limit                                                   |
|mail.yahoo.com          |                                                                                                                |
|www.bostonherald.com    |                                                                                                                |
|finance.yahoo.com       |                                                                                                                |
|finance.yahoo.com       |/quote/MRNA                                                                                                     |
|www.scarymommy.com      |/having-baby-during-pandemic-emotional                                                                          |
|www.minq.com            |/lifestyle/2563101/people-share-the-time-they-unapologetically-stood-up-to-their-entitled-in-laws               |
|en.kueez.com            |/50-of-the-most-epic-and-hilarious-sports-bloopers-of-all-tim                                                   |
|www.minq.com            |/lifestyle/2563101/people-share-the-time-they-unapologetically-stood-up-to-their-entitled-in-laws               |
|mobile.ghanaweb.com     |/GhanaHomePage/NewsArchive                                                                                      |
|mobile.ghanaweb.com     |/GhanaHomePage/NewsArchive                                                                                      |
|www.sparknotes.com      |/lit/flies/section2                                                                                             |
|mail.yahoo.com          |                                                                                                                |
|en.365economist.com     |/30-brilliant-solutions-that-will-make-the-best-of-your-limit                                                   |
|outlook.live.com        |                                                                                                                |
|brobible.com            |/sports/article/vivian-flores-butterfly-424-catfishing-allegations                                              |
|www.space.com           |/space-race.html                                                                                                |
|www.yahoo.com           |                                                                                                                |
|myhealthgazette.com     |/45-funny-air-travel-facts                                                                                      |
|medical-news.org        |/30-popular-foods-children-shouldnt-be-fed/12938/10                                                             |
|www.drivepedia.com      |/trending/finds-mysterious-internet-fb/6                                                                        |
|www.cbc.ca              |/news/technology/retail-chemicals-report-1.5976620                                                              |
|en.wackojaco.com        |/40-places-around-the-world-that-are-forbidden-to-travel-to                                                     |
|weather.com             |/weather/tenday/l/ff548795d9b9049e515ce9e8eee210ad30b0bcbf50339f14198db3910ffb06ce                              |
|word.tips               |/unscramble/eaofsod                                                                                             |
|mail.yahoo.com          |                                                                                                                |
|mail.yahoo.com          |                                                                                                                |
|www.wsfa.com            |/2021/04/19/killed-injured-sunday-montgomery-shooting                                                           |
|www.fox23.com           |/news/video-several-teachers-staff-members-resigning-catoosa-public-schools/525e9b3e-2c15-4495-8db2-72b80cb0bedb|
|www.theprimarymarket.com|/view/brilliant-japanese-design-tpm                                                                             |
|www.habsetlnh.com       |/Alex-Romanov-sonne-les-cloches-a-Jujhar-Khaira-39233                                                           |
|clashofclans.fandom.com |/wiki/O.T.T.O                                                                                                   |
|www.ranker.com          |/list/colonial-mash-v2/mel-judson                                                                               |
|comicbook.com           |/tv-shows/news/ginny-and-georgia-season-2-netflix-renewed-streaming                                             |
|finance.yahoo.com       |/quote/DOGE-USD                                                                                                 |
|mail.yahoo.com          |                                                                                                                |
|mail.yahoo.com          |                                                                                                                |
|mail.yahoo.com          |                                                                                                                |
|www.blackpeoplemeet.com |/v3/profile                                                                                                     |
|weather.com             |/weather/hourbyhour/l/c44f2773cda02fec98442b446569b1a196b72bcb73ca2acdcf864db6e4c2fc18                          |
+------------------------+----------------------------------------------------------------------------------------------------------------+
"""

# %%
for line in paths.split('\n')[4:-2]:
    
    pipe_split = line.split('|')
    domain = tldextract.extract(pipe_split[1]).domain
    line_path = pipe_split[2]
    
    sanitized = re.sub('\s+',' ',
           re.sub('[-|\./{0-9}]',' ',
                  domain+' '+line_path
            )
          )
    print(domain+' '+line_path)
    print(sanitized)
    print("\n".join([str(x) for x in ft_model.get_nearest_neighbors(sanitized)]))
    print('===============================================')
# Out:
# 365economist /30-brilliant-solutions-that-will-make-the-best-of-your-limit
#  economist brilliant solutions that will make the best of your limit
# (0.843499481678009, 'newcenturyinfusionsolutions')
# (0.8428196907043457, 'completedrugtestingsolutions')
# (0.8423277735710144, 'externalurlsmatchingthislistwillbeblockedwhenaddedtoapage')
# (0.8409328460693359, 'thedietsolutionprogram')
# (0.8395974040031433, 'hauntinginconnecticutultimatefansite')
# (0.8382377624511719, 'americanbeautytools')
# (0.8352340459823608, 'thevirtualsexreview')
# (0.8342839479446411, 'alfawebsolutions')
# (0.8342727422714233, 'americanswhotellthetruth')
# (0.8329175114631653, 'chevycitationforever')
# ===============================================
# yahoo
# yahoo
# (0.7627455592155457, 'yahoot')
# (0.7393791079521179, 'yahood')
# (0.7232840061187744, 'yahoofs')
# (0.7071269750595093, 'yahoo/ap')
# (0.7052602171897888, 'yahoo')
# (0.7041211724281311, 'yahoola')
# (0.6891429424285889, 'yahooey')
# (0.6888927221298218, 'yahoomail')
# (0.6888105273246765, 'yahooeys')
# (0.6826907992362976, 'yahooze')
# ===============================================
# bostonherald
# bostonherald
# (0.9598656296730042, 'bostonherald')
# (0.8810030817985535, '//bostonherald')
# (0.8148268461227417, 'bostonhitman')
# (0.8028989434242249, 'bostondailyglobe')
# (0.8021131157875061, 'boston+%')
# (0.79481041431427, 'com/bostonherald/access/')
# (0.7902539372444153, 'bostoncoc')
# (0.7738785743713379, 'bostonredcups')
# (0.7682057619094849, 'bostonphoenix')
# (0.7673568725585938, 'bostonhistory')
# ===============================================
# yahoo
# yahoo
# (0.7627455592155457, 'yahoot')
# (0.7393791079521179, 'yahood')
# (0.7232840061187744, 'yahoofs')
# (0.7071269750595093, 'yahoo/ap')
# (0.7052602171897888, 'yahoo')
# (0.7041211724281311, 'yahoola')
# (0.6891429424285889, 'yahooey')
# (0.6888927221298218, 'yahoomail')
# (0.6888105273246765, 'yahooeys')
# (0.6826907992362976, 'yahooze')
# ===============================================
# yahoo /quote/MRNA
# yahoo quote MRNA
# (0.681463360786438, 'goodquotes')
# (0.661691427230835, 'brainyquotes')
# (0.6615132093429565, 'freepoolquotes')
# (0.6600207686424255, 'brainyquote')
# (0.6594492793083191, 'bquote')
# (0.6591883301734924, 'choicequote')
# (0.6585270762443542, 'yahoofs')
# (0.656889796257019, 'endquote')
# (0.6547881364822388, 'freelegitonlinejob')
# (0.6535772681236267, 'quotewords')
# ===============================================
# scarymommy /having-baby-during-pandemic-emotional
# scarymommy having baby during pandemic emotional
# (0.8064250349998474, '/finalfantasyspiritswithin')
# (0.8051169514656067, '/elninjaturtlegueynofuealcaponecomod')
# (0.7970260381698608, 'wackywavinginflatablearmflailingtubeman')
# (0.7963390350341797, 'okkamagadudvdtelugumoviesongsfreedown')
# (0.7933220863342285, 'externalurlsmatchingthislistwillbeblockedwhenaddedtoapage')
# (0.790009081363678, 'wedreamofjeannie')
# (0.787848174571991, 'emotionfocusedclinic')
# (0.7855419516563416, 'setupmyfreeblastoffaccount')
# (0.7847915291786194, 'craptasticmovies')
# (0.7832257747650146, 'hauntinginconnecticutultimatefansite')
# ===============================================
# minq /lifestyle/2563101/people-share-the-time-they-unapologetically-stood-up-to-their-entitled-in-laws
# minq lifestyle people share the time they unapologetically stood up to their entitled in laws
# (0.7896780371665955, 'solipsisticnationpodcast')
# (0.7850480675697327, 'trinnyandsusannahwhattheydidnext')
# (0.7780812382698059, 'americanswhotellthetruth')
# (0.7665154337882996, 'externalurlsmatchingthislistwillbeblockedwhenaddedtoapage')
# (0.7664371728897095, 'wackywavinginflatablearmflailingtubeman')
# (0.7653451561927795, 'bigdaddyhorrorreviews')
# (0.764928936958313, 'thisreallyisnotjeffbryant')
# (0.7637803554534912, 'thenewpostliterate')
# (0.7629267573356628, 'smalltownromanceblog')
# (0.7611621022224426, 'thesurvivalistblog')
# ===============================================
# kueez /50-of-the-most-epic-and-hilarious-sports-bloopers-of-all-tim
# kueez of the most epic and hilarious sports bloopers of all tim
# (0.7981700301170349, 'wackywavinginflatablearmflailingtubeman')
# (0.7932041883468628, 'nationalforumongirlsfastpitchsoftball')
# (0.7871769070625305, '/elninjaturtlegueynofuealcaponecomod')
# (0.7867743968963623, 'thisreallyisnotjeffbryant')
# (0.7800648808479309, 'externalurlsmatchingthislistwillbeblockedwhenaddedtoapage')
# (0.7799789309501648, 'todosobrelosbeatlesya')
# (0.776400625705719, 'albumblancodiariodeunhinchadeallboys')
# (0.7753651738166809, 'hauntinginconnecticutultimatefansite')
# (0.7749258279800415, 'punkymanon')
# (0.774115264415741, 'thosewhostaywillbechampions')
# ===============================================
# minq /lifestyle/2563101/people-share-the-time-they-unapologetically-stood-up-to-their-entitled-in-laws
# minq lifestyle people share the time they unapologetically stood up to their entitled in laws
# (0.7896780371665955, 'solipsisticnationpodcast')
# (0.7850480675697327, 'trinnyandsusannahwhattheydidnext')
# (0.7780812382698059, 'americanswhotellthetruth')
# (0.7665154337882996, 'externalurlsmatchingthislistwillbeblockedwhenaddedtoapage')
# (0.7664371728897095, 'wackywavinginflatablearmflailingtubeman')
# (0.7653451561927795, 'bigdaddyhorrorreviews')
# (0.764928936958313, 'thisreallyisnotjeffbryant')
# (0.7637803554534912, 'thenewpostliterate')
# (0.7629267573356628, 'smalltownromanceblog')
# (0.7611621022224426, 'thesurvivalistblog')
# ===============================================
# ghanaweb /GhanaHomePage/NewsArchive
# ghanaweb GhanaHomePage NewsArchive
# (0.7708044052124023, 'ghanaweb')
# (0.7405527830123901, 'uk/africabeyond/africaonyourstreet/hosts/shaheera/')
# (0.7351629137992859, '//africanfootball')
# (0.732384204864502, 'uk/africabeyond/africaonyourstreet/features/')
# (0.731971025466919, 'kaieteurnewsonline')
# (0.728130042552948, 'southafricafacts')
# (0.7267830967903137, 'uk/africabeyond/africaonyourstreet/hosts/jjc/')
# (0.7239925861358643, 'uk/africabeyond/africaonyourstreet/cdreviews/')
# (0.7229064106941223, 'kenyanfootie')
# (0.7203112244606018, 'westafricanfootball')
# ===============================================
# ghanaweb /GhanaHomePage/NewsArchive
# ghanaweb GhanaHomePage NewsArchive
# (0.7708044052124023, 'ghanaweb')
# (0.7405527830123901, 'uk/africabeyond/africaonyourstreet/hosts/shaheera/')
# (0.7351629137992859, '//africanfootball')
# (0.732384204864502, 'uk/africabeyond/africaonyourstreet/features/')
# (0.731971025466919, 'kaieteurnewsonline')
# (0.728130042552948, 'southafricafacts')
# (0.7267830967903137, 'uk/africabeyond/africaonyourstreet/hosts/jjc/')
# (0.7239925861358643, 'uk/africabeyond/africaonyourstreet/cdreviews/')
# (0.7229064106941223, 'kenyanfootie')
# (0.7203112244606018, 'westafricanfootball')
# ===============================================
# sparknotes /lit/flies/section2
# sparknotes lit flies section
# (0.7297139763832092, 'sparknotes')
# (0.7283281683921814, 'com/hammock_physicist/fibonacci_butterflies')
# (0.7259327173233032, 'uk/earthscienceandengineering/rocklibrary/viewglossrecord')
# (0.7235362529754639, 'papersdeversalia')
# (0.7228097915649414, 'org/cspinosciencepubinterest')
# (0.7218567728996277, 'uk/schools/gcsebitesize/chemistry/usefulproductsrocks/chemicals_saltrev')
# (0.720537006855011, 'com/savepalestinenow/israellaws/fulltext/prescriptionlaw')
# (0.7200475931167603, 'com/scienza/erbario/utility/botanica_sistematica/hypertext/')
# (0.7197121977806091, 'largeformatprintingnewyork')
# (0.7192995548248291, 'com/witchofdarkness/winxclubcharacters')
# ===============================================
# yahoo
# yahoo
# (0.7627455592155457, 'yahoot')
# (0.7393791079521179, 'yahood')
# (0.7232840061187744, 'yahoofs')
# (0.7071269750595093, 'yahoo/ap')
# (0.7052602171897888, 'yahoo')
# (0.7041211724281311, 'yahoola')
# (0.6891429424285889, 'yahooey')
# (0.6888927221298218, 'yahoomail')
# (0.6888105273246765, 'yahooeys')
# (0.6826907992362976, 'yahooze')
# ===============================================
# 365economist /30-brilliant-solutions-that-will-make-the-best-of-your-limit
#  economist brilliant solutions that will make the best of your limit
# (0.843499481678009, 'newcenturyinfusionsolutions')
# (0.8428196907043457, 'completedrugtestingsolutions')
# (0.8423277735710144, 'externalurlsmatchingthislistwillbeblockedwhenaddedtoapage')
# (0.8409328460693359, 'thedietsolutionprogram')
# (0.8395974040031433, 'hauntinginconnecticutultimatefansite')
# (0.8382377624511719, 'americanbeautytools')
# (0.8352340459823608, 'thevirtualsexreview')
# (0.8342839479446411, 'alfawebsolutions')
# (0.8342727422714233, 'americanswhotellthetruth')
# (0.8329175114631653, 'chevycitationforever')
# ===============================================
# live
# live
# (0.6059824824333191, 'liveworks')
# (0.6030862927436829, 'liveu')
# (0.5562825798988342, 'videoworks')
# (0.5521219372749329, 'liveage')
# (0.5505928993225098, 'livepc')
# (0.5438240766525269, 'livead')
# (0.5420820713043213, 'livey')
# (0.5414988398551941, 'livedrive')
# (0.5388448238372803, '„live')
# (0.5369127988815308, 'grooveworx')
# ===============================================
# brobible /sports/article/vivian-flores-butterfly-424-catfishing-allegations
# brobible sports article vivian flores butterfly catfishing allegations
# (0.822613537311554, 'wackywavinginflatablearmflailingtubeman')
# (0.8183135390281677, 'bettymacdonaldfanclub')
# (0.8160726428031921, 'trinnyandsusannahwhattheydidnext')
# (0.8160501718521118, 'americanswhotellthetruth')
# (0.8122104406356812, 'meganfoxfans')
# (0.8087985515594482, 'americanbeautytools')
# (0.8069270849227905, 'hauntinginconnecticutultimatefansite')
# (0.8064619898796082, 'howcaniworkfromhomeandmakemoney')
# (0.8037869334220886, 'themysteryshoppingclub')
# (0.8036207556724548, 'royalcanadianpancakeshousesexplained')
# ===============================================
# space /space-race.html
# space space race html
# (0.7443194389343262, 'htmlplanet')
# (0.7189581990242004, 'mpl/space/')
# (0.7133204936981201, 'russianspaceweb')
# (0.7020996809005737, 'spacenews')
# (0.7014988660812378, '//spaceweather')
# (0.6993032097816467, 'theanyspacewhatever')
# (0.6964429616928101, 'rjplanet')
# (0.6961159110069275, 'spacesciencejournal')
# (0.6913345456123352, 'spaceclaim')
# (0.6907745003700256, 'gov/missions/solarsystem/bush_vision')
# ===============================================
# yahoo
# yahoo
# (0.7627455592155457, 'yahoot')
# (0.7393791079521179, 'yahood')
# (0.7232840061187744, 'yahoofs')
# (0.7071269750595093, 'yahoo/ap')
# (0.7052602171897888, 'yahoo')
# (0.7041211724281311, 'yahoola')
# (0.6891429424285889, 'yahooey')
# (0.6888927221298218, 'yahoomail')
# (0.6888105273246765, 'yahooeys')
# (0.6826907992362976, 'yahooze')
# ===============================================
# myhealthgazette /45-funny-air-travel-facts
# myhealthgazette funny air travel facts
# (0.8622646927833557, 'totalhealthguide')
# (0.85015869140625, 'letsgotravelsolutions')
# (0.8464009761810303, 'uk/life/livingandsocialcare/careandsupport/housingadvice/index')
# (0.8437775373458862, 'cosmeticplasticsurgeryholidayindia')
# (0.8390064239501953, 'koreahealthtour')
# (0.8385135531425476, 'yourhealthbase')
# (0.838026762008667, 'mobilecountyhealth')
# (0.8378739953041077, 'theleadingphysiciansoftheworld')
# (0.8372930288314819, 'whatishomehealthcare')
# (0.835374116897583, 'besthealthtourism')
# ===============================================
# medical-news /30-popular-foods-children-shouldnt-be-fed/12938/10
# medical news popular foods children shouldnt be fed
# (0.7832827568054199, 'healthynutritionguide')
# (0.7736809849739075, 'uk/life/livingandsocialcare/careandsupport/housingadvice/index')
# (0.7689370512962341, 'uk/schools/gcsebitesize/chemistry/usefulproductsrocks/chemicals_saltrev')
# (0.7653481364250183, 'recoveryfromfoodaddiction')
# (0.761483907699585, 'org/careforanimals/animatedjourneys/livingwithpets/poisoninfo')
# (0.7596256136894226, 'com/news/irishpost/news/americanlosesbattleoverleinsterdukeclaim')
# (0.7591753602027893, 'healthnewsreview')
# (0.7574777007102966, 'thecedarsdrugrehab')
# (0.7559689283370972, 'nz/news/healthnews/thebarbiedrug/tabid/')
# (0.7552290558815002, 'uk/healthydiet/nutritionessentials/vitaminsandminerals/vitaminc/')
# ===============================================
# drivepedia /trending/finds-mysterious-internet-fb/6
# drivepedia trending finds mysterious internet fb
# (0.8411262631416321, 'nyinternetlawyer')
# (0.8317393064498901, 'internetgatewaydevice')
# (0.8216181397438049, 'luthersinternetgadgetreview')
# (0.8184431195259094, 'freeonlinefaxsoftware')
# (0.8172292113304138, 'thevirtualsexreview')
# (0.8108060359954834, 'thedietsolutionprogram')
# (0.8101688623428345, 'theinternetgroup')
# (0.8065685629844666, 'thenigeriabusinessdirectory')
# (0.8056262135505676, 'livinginternet')
# (0.803774356842041, 'privateinternetaccess')
# ===============================================
# cbc /news/technology/retail-chemicals-report-1.5976620
# cbc news technology retail chemicals report
# (0.8586732745170593, 'cpatechnologyadvisor')
# (0.8489221930503845, 'disruptivetechnologyllc')
# (0.8353756070137024, 'advancedtechnologycentre')
# (0.8310766220092773, 'globalnettechnology')
# (0.8248271346092224, 'uk/schools/gcsebitesize/chemistry/usefulproductsrocks/chemicals_saltrev')
# (0.8193262815475464, 'com/products/xleratordbstatistics/xleratordbstatisticsdocumentation/tabid/')
# (0.8170948624610901, 'thetechnologyagency')
# (0.815601646900177, '//washingtontechnology')
# (0.8139849901199341, 'ca/en/canchildresources/virtualrealitytechnology')
# (0.810555636882782, 'technologynewsarticles')
# ===============================================
# wackojaco /40-places-around-the-world-that-are-forbidden-to-travel-to
# wackojaco places around the world that are forbidden to travel to
# (0.7883575558662415, 'disneyscaliforniaadventurelandingpage')
# (0.7818763852119446, 'insideluxurytravel')
# (0.7815204858779907, 'sacredtravelguide')
# (0.7759861350059509, 'com/witchofdarkness/winxclubcharacters')
# (0.7728131413459778, 'nepaltravelblogs')
# (0.7715739011764526, 'goplanettravel')
# (0.7704795002937317, 'thenightmyhome')
# (0.7698051929473877, 'bluelakesvacationrentals')
# (0.7694297432899475, 'bogotraveltours')
# (0.7688467502593994, 'indiahotelsandtours')
# ===============================================
# weather /weather/tenday/l/ff548795d9b9049e515ce9e8eee210ad30b0bcbf50339f14198db3910ffb06ce
# weather weather tenday l ff d b e ce e eee ad b bcbf f db ffb ce
# (0.7474948763847351, 'socalweather')
# (0.7472913861274719, 'skeetobiteweather')
# (0.7387657165527344, 'changefortheweather')
# (0.7192895412445068, 'ggweather')
# (0.7171279788017273, 'vaughanweather')
# (0.7166844010353088, 'essexweather')
# (0.7141863703727722, 'trinnyandsusannahwhattheydidnext')
# (0.7124199271202087, 'ustravelweather')
# (0.7096657752990723, 'mikeweatherleymp')
# (0.7094008326530457, 'carlowweather')
# ===============================================
# word /unscramble/eaofsod
# word unscramble eaofsod
# (0.6943871974945068, 'scramblecase')
# (0.6765424609184265, 'removeinitialcolon')
# (0.6700656414031982, 'rovingpersonalityconstruct')
# (0.6698230504989624, 'unscramble')
# (0.6661770343780518, 'msnpasswordcracker')
# (0.6636850237846375, 'multibytetowidechar')
# (0.6635690331459045, 'buttheadpackgoats')
# (0.6633955240249634, 'chbsllc')
# (0.6630221009254456, 'wackywavinginflatablearmflailingtubeman')
# (0.6586338877677917, 'unscrambler')
# ===============================================
# yahoo
# yahoo
# (0.7627455592155457, 'yahoot')
# (0.7393791079521179, 'yahood')
# (0.7232840061187744, 'yahoofs')
# (0.7071269750595093, 'yahoo/ap')
# (0.7052602171897888, 'yahoo')
# (0.7041211724281311, 'yahoola')
# (0.6891429424285889, 'yahooey')
# (0.6888927221298218, 'yahoomail')
# (0.6888105273246765, 'yahooeys')
# (0.6826907992362976, 'yahooze')
# ===============================================
# yahoo
# yahoo
# (0.7627455592155457, 'yahoot')
# (0.7393791079521179, 'yahood')
# (0.7232840061187744, 'yahoofs')
# (0.7071269750595093, 'yahoo/ap')
# (0.7052602171897888, 'yahoo')
# (0.7041211724281311, 'yahoola')
# (0.6891429424285889, 'yahooey')
# (0.6888927221298218, 'yahoomail')
# (0.6888105273246765, 'yahooeys')
# (0.6826907992362976, 'yahooze')
# ===============================================
# wsfa /2021/04/19/killed-injured-sunday-montgomery-shooting
# wsfa killed injured sunday montgomery shooting
# (0.7856919169425964, 'askyfilledwithshootingstars')
# (0.7565342783927917, 'johnstownchristianschool')
# (0.7544567584991455, 'lesamisdebeauforddelaney')
# (0.7497090697288513, 'ssrichardmontgomery')
# (0.7428973913192749, 'kevinmichaelrudd')
# (0.7426386475563049, 'tylermichaelconrad')
# (0.7361711859703064, 'montgomerycountymd')
# (0.7328778505325317, 'neckinjuryhelp')
# (0.7315297722816467, 'austinrobertbutler')
# (0.731046199798584, 'barburyshootingschool')
# ===============================================
# fox23 /news/video-several-teachers-staff-members-resigning-catoosa-public-schools/525e9b3e-2c15-4495-8db2-72b80cb0bedb
# fox news video several teachers staff members resigning catoosa public schools e b e c db b cb bedb
# (0.8485651016235352, 'ukschoolsdirectory')
# (0.8465105891227722, 'publicschoolsreport')
# (0.8281504511833191, 'lewistonpublicschools')
# (0.8262636661529541, 'org/virtualclassroom/stateofdebate/loveslabourslost')
# (0.8235378861427307, 'privateschoolsreport')
# (0.8227903842926025, 'topnursingschoolsph')
# (0.8192171454429626, 'houstonprivateschools')
# (0.8167739510536194, 'ncpublicschools')
# (0.8150011301040649, 'thenewschoolcounselor')
# (0.8146041035652161, 'uk/schools/gcsebitesize/chemistry/usefulproductsrocks/chemicals_saltrev')
# ===============================================
# theprimarymarket /view/brilliant-japanese-design-tpm
# theprimarymarket view brilliant japanese design tpm
# (0.8232360482215881, 'thebeautyofkinbaku')
# (0.8227890133857727, 'lucidshoppingdreams')
# (0.8168805837631226, 'onlinetradingconcepts')
# (0.8156676292419434, 'org/friendsofthepagoda/thepeacepagodaofnepaldocument')
# (0.8156063556671143, 'legacywebsitedesign')
# (0.8146618008613586, 'thenigeriabusinessdirectory')
# (0.8141209483146667, 'dontforgettotakeyourvitamins')
# (0.8136807084083557, 'howcaniworkfromhomeandmakemoney')
# (0.8131090998649597, 'websitedesigncom')
# (0.812187135219574, 'theparkbenchonline')
# ===============================================
# habsetlnh /Alex-Romanov-sonne-les-cloches-a-Jujhar-Khaira-39233
# habsetlnh Alex Romanov sonne les cloches a Jujhar Khaira
# (0.7747157216072083, 'soulyotrosalimentosdelalma')
# (0.767173707485199, 'de+tagle+bracho+y+perez+de+la+riva')
# (0.7631426453590393, 'revizyonilebrnckvvtmllttrhaberimatbaa')
# (0.7531834244728088, 'enoisnavibe')
# (0.7520881295204163, 'albumblancodiariodeunhinchadeallboys')
# (0.7511996030807495, 'amisdugolfedumorbihan')
# (0.749498188495636, 'hadiseacikgoz')
# (0.7489760518074036, '/elninjaturtlegueynofuealcaponecomod')
# (0.7480443716049194, 'huguesaufrayandco')
# (0.7470772862434387, 'la+cruz+que+chilla+y+las+reliquias+de+santa+generosa+de+ademuz')
# ===============================================
# fandom /wiki/O.T.T.O
# fandom wiki O T T O
# (0.719702422618866, 'wikipediaclubpune@gmail')
# (0.7177470326423645, 'listadmins')
# (0.715398371219635, 'wikipediaforum')
# (0.7143396139144897, 'freepublicdomainhorrormovies')
# (0.7113194465637207, 'softwarewikipedia')
# (0.7111548781394958, 'nikospokemonsite')
# (0.710605263710022, 'travianwiki')
# (0.7100054621696472, 'babynamespedia')
# (0.707927942276001, 'gentlemensclubpodcast')
# (0.7058802843093872, 'ddowiki')
# ===============================================
# ranker /list/colonial-mash-v2/mel-judson
# ranker list colonial mash v mel judson
# (0.7587873935699463, '/terrorsansfrontiersislamicmilitancyinnortheastindia')
# (0.7537142038345337, 'trinnyandsusannahwhattheydidnext')
# (0.7508990168571472, 'rankingoficialuruguay')
# (0.7497931122779846, 'thisweekinthecivilwar')
# (0.7497689127922058, 'soulyotrosalimentosdelalma')
# (0.7474657893180847, 'alaindelonlamiradadelcineeuropeo')
# (0.7442387342453003, 'hauntinginconnecticutultimatefansite')
# (0.7410057187080383, 'africanfacts')
# (0.7406699657440186, 'protectorateofsoutharabiamap')
# (0.7376779913902283, 'cinemaemfocoedwardewilsonstevens')
# ===============================================
# comicbook /tv-shows/news/ginny-and-georgia-season-2-netflix-renewed-streaming
# comicbook tv shows news ginny and georgia season netflix renewed streaming
# (0.8299289345741272, 'themovienetwork')
# (0.8286291360855103, 'lionkingbroadwayticketsonline')
# (0.824459433555603, 'com/witchofdarkness/winxclubcharacters')
# (0.8236891627311707, 'hauntinginconnecticutultimatefansite')
# (0.8205960392951965, 'theonlineprintcompany')
# (0.8204185962677002, '/power+social+shopping+networks')
# (0.8198389410972595, 'watchfreemoviesonlinedaily')
# (0.8194296956062317, 'nextgreatamericanbandblog')
# (0.8189671635627747, 'cartoonnetworktrfan')
# (0.8181143999099731, 'soweirdwebpageofficialsite')
# ===============================================
# yahoo /quote/DOGE-USD
# yahoo quote DOGE USD
# (0.6358513832092285, 'goodquotes')
# (0.6308130621910095, 'freepoolquotes')
# (0.6285233497619629, 'no_quotes')
# (0.6249220371246338, 'mainquotes')
# (0.6245983839035034, '_quotes')
# (0.6189131140708923, 'trinnyandsusannahwhattheydidnext')
# (0.6187325119972229, 'twainquotes')
# (0.6122023463249207, 'famousquotesfunnyquotes')
# (0.6086159944534302, 'spiritquotes')
# (0.6076653599739075, 'dentalinsurancequotes')
# ===============================================
# yahoo
# yahoo
# (0.7627455592155457, 'yahoot')
# (0.7393791079521179, 'yahood')
# (0.7232840061187744, 'yahoofs')
# (0.7071269750595093, 'yahoo/ap')
# (0.7052602171897888, 'yahoo')
# (0.7041211724281311, 'yahoola')
# (0.6891429424285889, 'yahooey')
# (0.6888927221298218, 'yahoomail')
# (0.6888105273246765, 'yahooeys')
# (0.6826907992362976, 'yahooze')
# ===============================================
# yahoo
# yahoo
# (0.7627455592155457, 'yahoot')
# (0.7393791079521179, 'yahood')
# (0.7232840061187744, 'yahoofs')
# (0.7071269750595093, 'yahoo/ap')
# (0.7052602171897888, 'yahoo')
# (0.7041211724281311, 'yahoola')
# (0.6891429424285889, 'yahooey')
# (0.6888927221298218, 'yahoomail')
# (0.6888105273246765, 'yahooeys')
# (0.6826907992362976, 'yahooze')
# ===============================================
# yahoo
# yahoo
# (0.7627455592155457, 'yahoot')
# (0.7393791079521179, 'yahood')
# (0.7232840061187744, 'yahoofs')
# (0.7071269750595093, 'yahoo/ap')
# (0.7052602171897888, 'yahoo')
# (0.7041211724281311, 'yahoola')
# (0.6891429424285889, 'yahooey')
# (0.6888927221298218, 'yahoomail')
# (0.6888105273246765, 'yahooeys')
# (0.6826907992362976, 'yahooze')
# ===============================================
# blackpeoplemeet /v3/profile
# blackpeoplemeet v profile
# (0.8504630923271179, 'blackpeoplemeet')
# (0.7477041482925415, '/myprofile/expressionprofile/profilephoto')
# (0.7456691265106201, 'liveprofile')
# (0.7346161007881165, 'ourprofile')
# (0.7246338725090027, 'americanprofile')
# (0.722527801990509, '/power+social+shopping+networks')
# (0.7218959927558899, 'yourhealthbase')
# (0.719569981098175, 'myspaceprofiles')
# (0.7163464426994324, 'culturalprofiles')
# (0.715205192565918, 'showbizprofile')
# ===============================================
# weather /weather/hourbyhour/l/c44f2773cda02fec98442b446569b1a196b72bcb73ca2acdcf864db6e4c2fc18
# weather weather hourbyhour l c f cda fec b b a b bcb ca acdcf db e c fc
# (0.7515979409217834, 'changefortheweather')
# (0.7470532059669495, 'mikeweatherleymp')
# (0.7445216774940491, 'carlowweather')
# (0.7370091676712036, 'lesamisdebeauforddelaney')
# (0.7368124127388, 'camarasdecctv')
# (0.7368050217628479, 'trinnyandsusannahwhattheydidnext')
# (0.7358216643333435, 'ustravelweather')
# (0.7352004051208496, 'setupmyfreeblastoffaccount')
# (0.7343571782112122, 'songsinthekeyofseptember')
# (0.7337045073509216, 'lesenfantsdelaliberte')
# ===============================================

# %%
for line in paths.split('\n')[4:-2]:
    
    pipe_split = line.split('|')
    domain = tldextract.extract(pipe_split[1]).domain
    line_path = pipe_split[2]
    
    sanitized = re.sub('\s+','_',
           re.sub('[-|\./{0-9}]',' ',
                  domain+' '+line_path
            )
          )
    print(domain+' '+line_path)
    print(sanitized)
    print("\n".join([str(x) for x in ft_model.get_nearest_neighbors(sanitized)]))
    print('===============================================')
# Out:
# 365economist /30-brilliant-solutions-that-will-make-the-best-of-your-limit
# _economist_brilliant_solutions_that_will_make_the_best_of_your_limit_
# (0.930489182472229, '_the_birds_the_wizard_and_the_vanishing_cabinet_rachezee_speaks_part_')
# (0.9297161102294922, 'com/david_houle/howard_bloom_on_the_future_of_energy_turn_poisons_into_pleasure_and_excrement_into_energy')
# (0.9279316663742065, 'the_scientific_consensus_holds_that_currently_marketed_gm_food_poses_no_greater_risk_than_conventional_food')
# (0.9266883134841919, 'candaules,_king_of_lydia,_shews_his_wife_by_stealth_to_gyges,_one_of_his_ministers,_as_she_goes_to_bed')
# (0.924230694770813, '_lb_meat_beef_modified_in_fat_content_with_tomato_and_or_catsup_on_bun')
# (0.9204339385032654, 'com/big_science_gambles/suit_alleges_cern_in_violation_of_human_rights')
# (0.9203583002090454, 'interpretive_work,_newfoundland_rangers_monthly_reports,_port_hope_simpson,_analysis_and_interpretation_')
# (0.916496992111206, 'com/news/kosovo_recognized_by_northern_cyprus_no_people_can_be_forced_to_live_under_the_rule_of_another')
# (0.9157387614250183, '_printz_award_for_excellence_in_young_adult_literature')
# (0.9157094359397888, 'suicides_at_the_golden_gate_bridge#steven_and_kellie_page')
# ===============================================
# yahoo
# yahoo_
# (0.7351774573326111, 'yahoofs')
# (0.6723772883415222, 'yahoot')
# (0.6662530303001404, 'yahoo/google')
# (0.6523705720901489, 'yahooey')
# (0.6505153179168701, 'yahoo')
# (0.6485353112220764, 'yahoo\\')
# (0.6436032652854919, 'yahoo%')
# (0.6403785943984985, 'yahoocojp')
# (0.6262702941894531, 'se/group/oasis+stopcryingyourheartout')
# (0.6255614161491394, 'com/user/younusharami')
# ===============================================
# bostonherald
# bostonherald_
# (0.893328845500946, 'bostonherald')
# (0.8463270664215088, '//bostonherald')
# (0.7884143590927124, 'com/bostonherald/access/')
# (0.7841740250587463, 'bostondailyglobe')
# (0.7688595056533813, 'boston+%')
# (0.7647401094436646, 'bostoncoc')
# (0.7564800381660461, 'bostonmagazine')
# (0.7555791139602661, 'bostonhistory')
# (0.7508289813995361, 'com/notesboston/notesbostoncontentpage')
# (0.7498425245285034, 'bostonhitman')
# ===============================================
# yahoo
# yahoo_
# (0.7351774573326111, 'yahoofs')
# (0.6723772883415222, 'yahoot')
# (0.6662530303001404, 'yahoo/google')
# (0.6523705720901489, 'yahooey')
# (0.6505153179168701, 'yahoo')
# (0.6485353112220764, 'yahoo\\')
# (0.6436032652854919, 'yahoo%')
# (0.6403785943984985, 'yahoocojp')
# (0.6262702941894531, 'se/group/oasis+stopcryingyourheartout')
# (0.6255614161491394, 'com/user/younusharami')
# ===============================================
# yahoo /quote/MRNA
# yahoo_quote_MRNA_
# (0.8156218528747559, 'no_quotes')
# (0.8135215640068054, '_quotes')
# (0.7858701348304749, 'com/quotations/topic/halloween_quotes/halloween_quotes')
# (0.7841213941574097, 'famousquotesfunnyquotes')
# (0.7776937484741211, 'com/quotations/topic/christmas_quotes/christmas_quotes')
# (0.7718034386634827, 'ch/e/zeitungsartikel/pdf/ganser_isn_gladio_security_watch_')
# (0.7717229723930359, 'kern_quotes')
# (0.7675822973251343, 'ro/meridianele_credintei_manastirea_bacikovo___perla_gruzina_a_muntilor_rodopi')
# (0.7661635279655457, 'ru/_quote_show_/java/')
# (0.7629210948944092, 'com/quotes/halloween_quotes/')
# ===============================================
# scarymommy /having-baby-during-pandemic-emotional
# scarymommy_having_baby_during_pandemic_emotional_
# (0.9185893535614014, 'candaules,_king_of_lydia,_shews_his_wife_by_stealth_to_gyges,_one_of_his_ministers,_as_she_goes_to_bed')
# (0.9164403676986694, 'original_casting_from_the_bronze_doors_made_by_lorenzo_ghiberti')
# (0.9137622117996216, '_clarifying_policy_on_pictures_of_deceased_persons')
# (0.9135603904724121, 'looking_south_east_at_the_lincoln_monument_of_wabash,_indiana_by_charles_keck')
# (0.9082091450691223, 'royal_commission_into_the_protection_and_detention_of_children_in_the_northern_territory')
# (0.9080721139907837, 'rice_university/poverty,_gender,_and_human_development_section_')
# (0.9077630639076233, '#recusing_myself_from_wikipedia_because_of_allegations_of_disruptive_editing')
# (0.9071385860443115, '_clumsy_blond_woman_trying_to_climb_a_ladder_in_heels_falling_over')
# (0.9070937633514404, 'did_you_hear_what_happened_to_charlotte_king%')
# (0.9059802293777466, '/do_computer_scientists_deeply_understand_the_traditional_arabic_morphology_%d')
# ===============================================
# minq /lifestyle/2563101/people-share-the-time-they-unapologetically-stood-up-to-their-entitled-in-laws
# minq_lifestyle_people_share_the_time_they_unapologetically_stood_up_to_their_entitled_in_laws_
# (0.9511651992797852, 'com/news/kosovo_recognized_by_northern_cyprus_no_people_can_be_forced_to_live_under_the_rule_of_another')
# (0.9455176591873169, '_lb_meat_beef_modified_in_fat_content_with_tomato_and_or_catsup_on_bun')
# (0.9433555603027344, '/to_catch_a_predator_is_nbcs_primetime_dragnet_the_new_american_witch_hunt/')
# (0.9424318671226501, 'candaules,_king_of_lydia,_shews_his_wife_by_stealth_to_gyges,_one_of_his_ministers,_as_she_goes_to_bed')
# (0.9413027167320251, '_hdd_gets_an_in_depth_look_at_the_restoration_of_the_wizard_of_oz_%')
# (0.9397730827331543, 'com/david_houle/howard_bloom_on_the_future_of_energy_turn_poisons_into_pleasure_and_excrement_into_energy')
# (0.9383377432823181, 'people_charged_by_the_special_court_for_sierra_leone')
# (0.9362106919288635, '/_but_me_no_buts_the_theological_debate_between_the_hasidim_and_the_mitnagdim_in_light_of_the_discourse')
# (0.9330244064331055, 'royal_commission_into_the_protection_and_detention_of_children_in_the_northern_territory')
# (0.93272864818573, '_the_birds_the_wizard_and_the_vanishing_cabinet_rachezee_speaks_part_')
# ===============================================
# kueez /50-of-the-most-epic-and-hilarious-sports-bloopers-of-all-tim
# kueez_of_the_most_epic_and_hilarious_sports_bloopers_of_all_tim_
# (0.9441404938697815, 'institute_of_the_brothers_of_the_christian_schools')
# (0.9422506093978882, 'grand_masters_of_the_teutonic_order')
# (0.936555802822113, 'rivers_and_streams_of_the_san_francisco_bay_area')
# (0.9360594153404236, '/peter_travers_best_and_worst_movies_of_')
# (0.9359623789787292, 'members_and_leaders_of_the_praetorian_guard')
# (0.9359179139137268, 'rivers_of_the_democratic_republic_of_the_congo')
# (0.9351277947425842, '_hdd_gets_an_in_depth_look_at_the_restoration_of_the_wizard_of_oz_%')
# (0.9331513047218323, 'grand_masters_of_the_order_of_parfaite_amiti%c')
# (0.9318642020225525, 'rivers_of_the_central_african_republic')
# (0.9316701889038086, 'rivers_of_the_central_bohemian_region')
# ===============================================
# minq /lifestyle/2563101/people-share-the-time-they-unapologetically-stood-up-to-their-entitled-in-laws
# minq_lifestyle_people_share_the_time_they_unapologetically_stood_up_to_their_entitled_in_laws_
# (0.9511651992797852, 'com/news/kosovo_recognized_by_northern_cyprus_no_people_can_be_forced_to_live_under_the_rule_of_another')
# (0.9455176591873169, '_lb_meat_beef_modified_in_fat_content_with_tomato_and_or_catsup_on_bun')
# (0.9433555603027344, '/to_catch_a_predator_is_nbcs_primetime_dragnet_the_new_american_witch_hunt/')
# (0.9424318671226501, 'candaules,_king_of_lydia,_shews_his_wife_by_stealth_to_gyges,_one_of_his_ministers,_as_she_goes_to_bed')
# (0.9413027167320251, '_hdd_gets_an_in_depth_look_at_the_restoration_of_the_wizard_of_oz_%')
# (0.9397730827331543, 'com/david_houle/howard_bloom_on_the_future_of_energy_turn_poisons_into_pleasure_and_excrement_into_energy')
# (0.9383377432823181, 'people_charged_by_the_special_court_for_sierra_leone')
# (0.9362106919288635, '/_but_me_no_buts_the_theological_debate_between_the_hasidim_and_the_mitnagdim_in_light_of_the_discourse')
# (0.9330244064331055, 'royal_commission_into_the_protection_and_detention_of_children_in_the_northern_territory')
# (0.93272864818573, '_the_birds_the_wizard_and_the_vanishing_cabinet_rachezee_speaks_part_')
# ===============================================
# ghanaweb /GhanaHomePage/NewsArchive
# ghanaweb_GhanaHomePage_NewsArchive_
# (0.7703456282615662, 'lewis_libby/archive_')
# (0.7661480903625488, '_archive_')
# (0.754056990146637, 'toi_pune_archive_')
# (0.7515843510627747, 'irish_potato_famine/archive_')
# (0.7458950877189636, 'malik_shabazz/archive_')
# (0.7433903813362122, 'wlu/archive_')
# (0.7429139018058777, 'scuro/archive_')
# (0.7383445501327515, 'tony_sidaway/archive_')
# (0.736320436000824, 'farchive_')
# (0.7359966039657593, '_archive_july_')
# ===============================================
# ghanaweb /GhanaHomePage/NewsArchive
# ghanaweb_GhanaHomePage_NewsArchive_
# (0.7703456282615662, 'lewis_libby/archive_')
# (0.7661480903625488, '_archive_')
# (0.754056990146637, 'toi_pune_archive_')
# (0.7515843510627747, 'irish_potato_famine/archive_')
# (0.7458950877189636, 'malik_shabazz/archive_')
# (0.7433903813362122, 'wlu/archive_')
# (0.7429139018058777, 'scuro/archive_')
# (0.7383445501327515, 'tony_sidaway/archive_')
# (0.736320436000824, 'farchive_')
# (0.7359966039657593, '_archive_july_')
# ===============================================
# sparknotes /lit/flies/section2
# sparknotes_lit_flies_section_
# (0.871456503868103, '_lb_meat_beef_modified_in_fat_content_with_tomato_and_or_catsup_on_bun')
# (0.8669083118438721, '/jung_in_love_the_mysterium_in_liber_novus_full_monograph_edition_')
# (0.8657764792442322, '/the_cleopatra_files_selected_documents_from_the_spyros_p')
# (0.8632071614265442, '_section_')
# (0.8619597554206848, '/world_s_first_commercial_scale_tidal_power_system_feeds_electricity_to_the_national_grid__/')
# (0.8617279529571533, '#country_profile_section_')
# (0.8609716892242432, '/f/jones_sexless_marriage_sextures_volume_')
# (0.8607122898101807, 'cite_section_preview_references')
# (0.8595304489135742, '_rba_and_reform_of_the_currency/australias_first_decimal_currency_notes')
# (0.858138918876648, 'interpretive_work,_newfoundland_rangers_monthly_reports,_port_hope_simpson,_analysis_and_interpretation_')
# ===============================================
# yahoo
# yahoo_
# (0.7351774573326111, 'yahoofs')
# (0.6723772883415222, 'yahoot')
# (0.6662530303001404, 'yahoo/google')
# (0.6523705720901489, 'yahooey')
# (0.6505153179168701, 'yahoo')
# (0.6485353112220764, 'yahoo\\')
# (0.6436032652854919, 'yahoo%')
# (0.6403785943984985, 'yahoocojp')
# (0.6262702941894531, 'se/group/oasis+stopcryingyourheartout')
# (0.6255614161491394, 'com/user/younusharami')
# ===============================================
# 365economist /30-brilliant-solutions-that-will-make-the-best-of-your-limit
# _economist_brilliant_solutions_that_will_make_the_best_of_your_limit_
# (0.930489182472229, '_the_birds_the_wizard_and_the_vanishing_cabinet_rachezee_speaks_part_')
# (0.9297161102294922, 'com/david_houle/howard_bloom_on_the_future_of_energy_turn_poisons_into_pleasure_and_excrement_into_energy')
# (0.9279316663742065, 'the_scientific_consensus_holds_that_currently_marketed_gm_food_poses_no_greater_risk_than_conventional_food')
# (0.9266883134841919, 'candaules,_king_of_lydia,_shews_his_wife_by_stealth_to_gyges,_one_of_his_ministers,_as_she_goes_to_bed')
# (0.924230694770813, '_lb_meat_beef_modified_in_fat_content_with_tomato_and_or_catsup_on_bun')
# (0.9204339385032654, 'com/big_science_gambles/suit_alleges_cern_in_violation_of_human_rights')
# (0.9203583002090454, 'interpretive_work,_newfoundland_rangers_monthly_reports,_port_hope_simpson,_analysis_and_interpretation_')
# (0.916496992111206, 'com/news/kosovo_recognized_by_northern_cyprus_no_people_can_be_forced_to_live_under_the_rule_of_another')
# (0.9157387614250183, '_printz_award_for_excellence_in_young_adult_literature')
# (0.9157094359397888, 'suicides_at_the_golden_gate_bridge#steven_and_kellie_page')
# ===============================================
# live
# live_
# (0.9214595556259155, 'alive_')
# (0.8442429304122925, 'eve_')
# (0.8057811260223389, 'love_')
# (0.7430484890937805, 'farchive_')
# (0.7301803827285767, 'archive_')
# (0.7203712463378906, '/archive_')
# (0.7147560119628906, 'tavix/archive_')
# (0.6937943696975708, 'wlu/archive_')
# (0.6919739246368408, 'w/archive_')
# (0.6826624870300293, '_archive_')
# ===============================================
# brobible /sports/article/vivian-flores-butterfly-424-catfishing-allegations
# brobible_sports_article_vivian_flores_butterfly_catfishing_allegations_
# (0.9408165812492371, 'com/news/kosovo_recognized_by_northern_cyprus_no_people_can_be_forced_to_live_under_the_rule_of_another')
# (0.9396899938583374, 'candaules,_king_of_lydia,_shews_his_wife_by_stealth_to_gyges,_one_of_his_ministers,_as_she_goes_to_bed')
# (0.9371047019958496, '_lb_meat_beef_modified_in_fat_content_with_tomato_and_or_catsup_on_bun')
# (0.9357182383537292, 'com/david_houle/howard_bloom_on_the_future_of_energy_turn_poisons_into_pleasure_and_excrement_into_energy')
# (0.9332309365272522, '_clumsy_blond_woman_trying_to_climb_a_ladder_in_heels_falling_over')
# (0.9290803074836731, 'com/pizza_chains_eye_slice_of_each_others_pie_posted_by_michael_fomkin')
# (0.9271701574325562, 'interpretive_work,_newfoundland_rangers_monthly_reports,_port_hope_simpson,_analysis_and_interpretation_')
# (0.9270878434181213, 'de/artikel_von_riverkill_de/poker_literatur/buchtipp_barry_greenstein_ace_on_the_river_')
# (0.9264898896217346, '_should_this_article_mention_current_lawsuits_by_u')
# (0.9257237315177917, '/shes_the_sixties_icon_who_had_a_child_by_mick/index')
# ===============================================
# space /space-race.html
# space_space_race_html_
# (0.8991914987564087, 'th_space_group')
# (0.8790196180343628, 'th_space_control_squadron')
# (0.8787021040916443, 'th_space_wing')
# (0.872240424156189, '/space_stalwart')
# (0.8590255379676819, 'space_tribe%')
# (0.857078492641449, 'space_rock')
# (0.8516575694084167, 'space_filling_tree_square')
# (0.8515064716339111, 'st_space_wing')
# (0.8512704372406006, '_automotive_truck_van_and_suv_oem_replacement_spark_plug_pack_of_')
# (0.8495080471038818, 'com/spotlights/rehearsal_space_anton_newcombe')
# ===============================================
# yahoo
# yahoo_
# (0.7351774573326111, 'yahoofs')
# (0.6723772883415222, 'yahoot')
# (0.6662530303001404, 'yahoo/google')
# (0.6523705720901489, 'yahooey')
# (0.6505153179168701, 'yahoo')
# (0.6485353112220764, 'yahoo\\')
# (0.6436032652854919, 'yahoo%')
# (0.6403785943984985, 'yahoocojp')
# (0.6262702941894531, 'se/group/oasis+stopcryingyourheartout')
# (0.6255614161491394, 'com/user/younusharami')
# ===============================================
# myhealthgazette /45-funny-air-travel-facts
# myhealthgazette_funny_air_travel_facts_
# (0.892553985118866, '/with_kerry_out_key_aide_shifts_to_ospammer/')
# (0.8905794620513916, 'def/disney_reveals_new_specs,_exclusive_extras_for_lost')
# (0.8903961181640625, '/rebecca_loos_new_single_what_happens_after_a_celebrity_sex_scandal/')
# (0.8900508284568787, 'livestation_reveals_global_appetite_for_live_tv_news_online')
# (0.8898140788078308, '/press_release/serengeti_selects_a_new_ambassador_from_desperate_housewives_')
# (0.8896844387054443, 'com/index_home_acura_audi_bmw_cadillac_chevrolet_dodge_ford_gmc_honda_infiniti_lexus_mercedes_mitsubishi_nissan_toyota_vw_body_kits_ground_effects')
# (0.8888590931892395, '/business/overstock_com_lashes_out_at_critics_on_web_business_roddy_boyd')
# (0.8855936527252197, '/leahy_endorses_ospammer_likens_him_to_bobby_kennedy')
# (0.8844529390335083, '/gossip/cindy/yes_on_dubya_apology__frost_cindy_cindy_adams')
# (0.8829237818717957, 'com/vanessa_hudgens_nude_photo_it_is_unfortunate_this_has_become_public')
# ===============================================
# medical-news /30-popular-foods-children-shouldnt-be-fed/12938/10
# medical_news_popular_foods_children_shouldnt_be_fed_
# (0.932324230670929, 'com/news/kosovo_recognized_by_northern_cyprus_no_people_can_be_forced_to_live_under_the_rule_of_another')
# (0.9301316738128662, '_lb_meat_beef_modified_in_fat_content_with_tomato_and_or_catsup_on_bun')
# (0.9232504963874817, 'com/pizza_chains_eye_slice_of_each_others_pie_posted_by_michael_fomkin')
# (0.9210571646690369, 'livestation_reveals_global_appetite_for_live_tv_news_online')
# (0.9184335470199585, '/press_release/serengeti_selects_a_new_ambassador_from_desperate_housewives_')
# (0.9169965982437134, '/to_catch_a_predator_is_nbcs_primetime_dragnet_the_new_american_witch_hunt/')
# (0.9161631464958191, '/rebecca_loos_new_single_what_happens_after_a_celebrity_sex_scandal/')
# (0.9156445860862732, 'candaules,_king_of_lydia,_shews_his_wife_by_stealth_to_gyges,_one_of_his_ministers,_as_she_goes_to_bed')
# (0.9154441356658936, '/busting_child_pornography_real_and_imagined')
# (0.9140195846557617, '/tctd/aotw/animal_collective_merriweather_post_pavillion_too_rapidshare_or_not_too_rap/')
# ===============================================
# drivepedia /trending/finds-mysterious-internet-fb/6
# drivepedia_trending_finds_mysterious_internet_fb_
# (0.9240017533302307, 'org/onlinenews/vodafone_live_launches_cheaper_mobile_internet_portal_in_the_uk_')
# (0.9235112071037292, 'com/david_houle/howard_bloom_on_the_future_of_energy_turn_poisons_into_pleasure_and_excrement_into_energy')
# (0.9224862456321716, 'com/talks/srikumar_rao_plug_into_your_hard_wired_happiness')
# (0.9193746447563171, '_royal_society_prize_for_junior_science_book')
# (0.9181985259056091, 'interpretive_work,_newfoundland_rangers_monthly_reports,_port_hope_simpson,_analysis_and_interpretation_')
# (0.9163938760757446, '_clumsy_blond_woman_trying_to_climb_a_ladder_in_heels_falling_over')
# (0.9155840277671814, '_printz_award_for_excellence_in_young_adult_literature')
# (0.9127201437950134, 'com/storecontent/thomson_m&a/united_internet_ag_acquires_a_minority_stake_in_jimdo_gmbh')
# (0.9114860892295837, 'candaules,_king_of_lydia,_shews_his_wife_by_stealth_to_gyges,_one_of_his_ministers,_as_she_goes_to_bed')
# (0.9113175272941589, 'livestation_reveals_global_appetite_for_live_tv_news_online')
# ===============================================
# cbc /news/technology/retail-chemicals-report-1.5976620
# cbc_news_technology_retail_chemicals_report_
# (0.911544919013977, '/business/overstock_com_lashes_out_at_critics_on_web_business_roddy_boyd')
# (0.9073376059532166, '_global_tv_revenues_decline_lcdtv_revenues_down_units_up_samsung_claims_top_spot')
# (0.9071475863456726, 'com/en/encelium_technologies_energy_savings_whitepaper')
# (0.9061266183853149, 'com/news_releases/weav_patent_application_for_a_plasma_propelled_flying_saucer')
# (0.9043123722076416, 'com/news_releases/tissueengineered_trachea_transplant_adult_stem_cell_breakthrough')
# (0.9040061235427856, 'com/news/ge_unveils_new_energy_smart_led_bulb_')
# (0.9037712812423706, 'xsl/strong_mini_note_shipments_buoy_notebook_pc_market_q')
# (0.9000714421272278, '/latest_iphone_software_supports_full_screen_web_apps')
# (0.8999173641204834, 'com/golf_news/serafin_designing_new_nine_at_lakeland_golf_course')
# (0.8997759222984314, 'livestation_reveals_global_appetite_for_live_tv_news_online')
# ===============================================
# wackojaco /40-places-around-the-world-that-are-forbidden-to-travel-to
# wackojaco_places_around_the_world_that_are_forbidden_to_travel_to_
# (0.9385167360305786, 'com/news/kosovo_recognized_by_northern_cyprus_no_people_can_be_forced_to_live_under_the_rule_of_another')
# (0.9306651949882507, 'com/david_houle/howard_bloom_on_the_future_of_energy_turn_poisons_into_pleasure_and_excrement_into_energy')
# (0.9299360513687134, '_lb_meat_beef_modified_in_fat_content_with_tomato_and_or_catsup_on_bun')
# (0.9297215342521667, '_clumsy_blond_woman_trying_to_climb_a_ladder_in_heels_falling_over')
# (0.9225766062736511, 'people_charged_by_the_special_court_for_sierra_leone')
# (0.9224733710289001, '/shes_the_sixties_icon_who_had_a_child_by_mick/index')
# (0.9207435846328735, 'com/news/scientists_track_migration_of_asian_dust_and_pollution')
# (0.9200376868247986, '_the_birds_the_wizard_and_the_vanishing_cabinet_rachezee_speaks_part_')
# (0.919278085231781, 'candaules,_king_of_lydia,_shews_his_wife_by_stealth_to_gyges,_one_of_his_ministers,_as_she_goes_to_bed')
# (0.9175310730934143, 'com/q/what_are_the_gang_names_in_denver_colorado')
# ===============================================
# weather /weather/tenday/l/ff548795d9b9049e515ce9e8eee210ad30b0bcbf50339f14198db3910ffb06ce
# weather_weather_tenday_l_ff_d_b_e_ce_e_eee_ad_b_bcbf_f_db_ffb_ce_
# (0.9045459032058716, '_automotive_truck_van_and_suv_oem_replacement_spark_plug_pack_of_')
# (0.9045075178146362, '/world_s_first_commercial_scale_tidal_power_system_feeds_electricity_to_the_national_grid__/')
# (0.9026677012443542, '_visitors_flock_to_urbis_as_revamp_pays_off')
# (0.9020921587944031, '/mary_j_blige_no_more_growing_pains_no')
# (0.9020739197731018, '_clumsy_blond_woman_trying_to_climb_a_ladder_in_heels_falling_over')
# (0.9008674621582031, 'com/index_home_acura_audi_bmw_cadillac_chevrolet_dodge_ford_gmc_honda_infiniti_lexus_mercedes_mitsubishi_nissan_toyota_vw_body_kits_ground_effects')
# (0.9006945490837097, 'de_singapore_flyer_beats_london_eye')
# (0.8977516293525696, 'com/pizza_chains_eye_slice_of_each_others_pie_posted_by_michael_fomkin')
# (0.8965249061584473, 'de/artikel_von_riverkill_de/poker_literatur/buchtipp_barry_greenstein_ace_on_the_river_')
# (0.8958147168159485, '/tctd/aotw/animal_collective_merriweather_post_pavillion_too_rapidshare_or_not_too_rap/')
# ===============================================
# word /unscramble/eaofsod
# word_unscramble_eaofsod_
# (0.8126381039619446, '/dr_michael_egnor_challenges_ev')
# (0.8125409483909607, '/hallan_restos_arqueologicos_del_s_iv_ac_')
# (0.8114548325538635, 'permission_form_to_use_photos_from_san_francisco_library_james_carroll_a')
# (0.8103442192077637, '_royal_society_prize_for_junior_science_book')
# (0.8083223104476929, 'the_scientific_consensus_holds_that_currently_marketed_gm_food_poses_no_greater_risk_than_conventional_food')
# (0.808055579662323, 'interpretive_work,_newfoundland_rangers_monthly_reports,_port_hope_simpson,_analysis_and_interpretation_')
# (0.8070517778396606, '/french_journalist_henri_alleg_describes_his')
# (0.8067226409912109, '_let_it_die_foo_fighters')
# (0.8054622411727905, 'com/ar,robert_bourgi_un_intermediaire_francafricain_sur_le_declin_,')
# (0.8048452734947205, 'org/twikibar/webhome#livro_de_shell_em_portugu_s')
# ===============================================
# yahoo
# yahoo_
# (0.7351774573326111, 'yahoofs')
# (0.6723772883415222, 'yahoot')
# (0.6662530303001404, 'yahoo/google')
# (0.6523705720901489, 'yahooey')
# (0.6505153179168701, 'yahoo')
# (0.6485353112220764, 'yahoo\\')
# (0.6436032652854919, 'yahoo%')
# (0.6403785943984985, 'yahoocojp')
# (0.6262702941894531, 'se/group/oasis+stopcryingyourheartout')
# (0.6255614161491394, 'com/user/younusharami')
# ===============================================
# yahoo
# yahoo_
# (0.7351774573326111, 'yahoofs')
# (0.6723772883415222, 'yahoot')
# (0.6662530303001404, 'yahoo/google')
# (0.6523705720901489, 'yahooey')
# (0.6505153179168701, 'yahoo')
# (0.6485353112220764, 'yahoo\\')
# (0.6436032652854919, 'yahoo%')
# (0.6403785943984985, 'yahoocojp')
# (0.6262702941894531, 'se/group/oasis+stopcryingyourheartout')
# (0.6255614161491394, 'com/user/younusharami')
# ===============================================
# wsfa /2021/04/19/killed-injured-sunday-montgomery-shooting
# wsfa_killed_injured_sunday_montgomery_shooting_
# (0.9213022589683533, 'aviators_killed_in_shootdowns')
# (0.914238691329956, '_shooting_of_dallas_police_officers')
# (0.9132828712463379, 'people_charged_by_the_special_court_for_sierra_leone')
# (0.9091780185699463, 'people_convicted_by_the_international_criminal_tribunal_for_rwanda')
# (0.9084880352020264, 'old_west_palm_beach_national_guard_armory')
# (0.9083051085472107, '_italian_navy_marines_shooting_incident_in_the_laccadive_sea')
# (0.908216655254364, 'american_expeditionary_forces_on_the_western_front_')
# (0.9076095819473267, 'looking_south_east_at_the_lincoln_monument_of_wabash,_indiana_by_charles_keck')
# (0.9071168303489685, 'people_charged_by_the_international_criminal_tribunal_for_rwanda')
# (0.9063718914985657, 'candaules,_king_of_lydia,_shews_his_wife_by_stealth_to_gyges,_one_of_his_ministers,_as_she_goes_to_bed')
# ===============================================
# fox23 /news/video-several-teachers-staff-members-resigning-catoosa-public-schools/525e9b3e-2c15-4495-8db2-72b80cb0bedb
# fox_news_video_several_teachers_staff_members_resigning_catoosa_public_schools_e_b_e_c_db_b_cb_bedb
# (0.9260772466659546, '/tctd/aotw/animal_collective_merriweather_post_pavillion_too_rapidshare_or_not_too_rap/')
# (0.9223325252532959, 'com/news/article/teen_charged_in_teacher_attack_returning_to_school/')
# (0.9201963543891907, '_visitors_flock_to_urbis_as_revamp_pays_off')
# (0.9199761748313904, 'com/pizza_chains_eye_slice_of_each_others_pie_posted_by_michael_fomkin')
# (0.9152681231498718, '/rebecca_loos_new_single_what_happens_after_a_celebrity_sex_scandal/')
# (0.9151464104652405, '/press_release/serengeti_selects_a_new_ambassador_from_desperate_housewives_')
# (0.9144330620765686, 'de/artikel_von_riverkill_de/poker_literatur/buchtipp_barry_greenstein_ace_on_the_river_')
# (0.9141152501106262, 'com/golf_news/serafin_designing_new_nine_at_lakeland_golf_course')
# (0.9117845296859741, '_clumsy_blond_woman_trying_to_climb_a_ladder_in_heels_falling_over')
# (0.9103558659553528, 'blue_star_mothers_club')
# ===============================================
# theprimarymarket /view/brilliant-japanese-design-tpm
# theprimarymarket_view_brilliant_japanese_design_tpm_
# (0.8927494883537292, 'com/index_home_acura_audi_bmw_cadillac_chevrolet_dodge_ford_gmc_honda_infiniti_lexus_mercedes_mitsubishi_nissan_toyota_vw_body_kits_ground_effects')
# (0.8911581635475159, 'com/golf_news/serafin_designing_new_nine_at_lakeland_golf_course')
# (0.8881927728652954, '/director_robert_wise_was_a_master_craftsman')
# (0.883722722530365, '/teban_gardens_road_market_and_food_centre/map')
# (0.882884681224823, '_visitors_flock_to_urbis_as_revamp_pays_off')
# (0.8823914527893066, 'com/david_houle/howard_bloom_on_the_future_of_energy_turn_poisons_into_pleasure_and_excrement_into_energy')
# (0.8807194828987122, '/book_excerpt_inside_game_design_')
# (0.8806129097938538, '/the_four_tops_bands_classic_interview_')
# (0.8766332268714905, '_global_tv_revenues_decline_lcdtv_revenues_down_units_up_samsung_claims_top_spot')
# (0.8747096657752991, '_submarine_networks_singapore_presentation')
# ===============================================
# habsetlnh /Alex-Romanov-sonne-les-cloches-a-Jujhar-Khaira-39233
# habsetlnh_Alex_Romanov_sonne_les_cloches_a_Jujhar_Khaira_
# (0.9273121356964111, 'ricardo_bofill_taller_de_arquitectura_les_echelles_du_baroque_paris')
# (0.9101452827453613, 'com/index_home_acura_audi_bmw_cadillac_chevrolet_dodge_ford_gmc_honda_infiniti_lexus_mercedes_mitsubishi_nissan_toyota_vw_body_kits_ground_effects')
# (0.909327507019043, 'porte_mars_arch,_reims,_france_')
# (0.9059982895851135, '/el_hallazgo_en_ruaya_descubre_una_ruta_c')
# (0.9055200219154358, 'les_costumes_populaires_de_la_turquie_en_')
# (0.9033485054969788, '/hallan_restos_arqueologicos_del_s_iv_ac_')
# (0.8994662165641785, 'com/ar,robert_bourgi_un_intermediaire_francafricain_sur_le_declin_,')
# (0.8987646698951721, '/valencia_en_la_guerra_de_la_independenci')
# (0.8980164527893066, '/novetats_sobre_el_sistema_dual_de_diferenciacio_grafica_de_les_oclusives_sordes_i_sonores')
# (0.8968878984451294, '_global_tv_revenues_decline_lcdtv_revenues_down_units_up_samsung_claims_top_spot')
# ===============================================
# fandom /wiki/O.T.T.O
# fandom_wiki_O_T_T_O_
# (0.8106273412704468, 'welcome_to_wikipedia/user')
# (0.790100634098053, 'org/wikistats/wikipedias_wiki')
# (0.7823922038078308, 'check_wiki_project_page')
# (0.7808491587638855, 'what_wikipedia_is_not')
# (0.7790026068687439, 'paolonapolitano/wikipedia_review_user_list')
# (0.7714496850967407, 'what_wikipedia_is_not#wikipedia_is_not_a_newspaper')
# (0.7712523937225342, 's_wikipedia_article')
# (0.767636775970459, 'awhat_wikipedia_is_not')
# (0.766620397567749, 'en_wikipedia')
# (0.7652516961097717, 'what_wikipedia_is_not#the_consensus_so_far')
# ===============================================
# ranker /list/colonial-mash-v2/mel-judson
# ranker_list_colonial_mash_v_mel_judson_
# (0.9220341444015503, '_lb_meat_beef_modified_in_fat_content_with_tomato_and_or_catsup_on_bun')
# (0.9178858399391174, 'candaules,_king_of_lydia,_shews_his_wife_by_stealth_to_gyges,_one_of_his_ministers,_as_she_goes_to_bed')
# (0.9174675941467285, '/mary_j_blige_no_more_growing_pains_no')
# (0.9165287017822266, '/world_s_first_commercial_scale_tidal_power_system_feeds_electricity_to_the_national_grid__/')
# (0.9115835428237915, '_clumsy_blond_woman_trying_to_climb_a_ladder_in_heels_falling_over')
# (0.9091269969940186, '_royal_society_prize_for_junior_science_book')
# (0.9083476662635803, '_printz_award_for_excellence_in_young_adult_literature')
# (0.9078614711761475, 'the_scientific_consensus_holds_that_currently_marketed_gm_food_poses_no_greater_risk_than_conventional_food')
# (0.9075204730033875, 'th_independent_battery_michigan_light_artillery')
# (0.9072983860969543, 'parker_monument_at_the_entrance_to_the_old_burying_ground_in_halifax,_nova_scotia,_canada')
# ===============================================
# comicbook /tv-shows/news/ginny-and-georgia-season-2-netflix-renewed-streaming
# comicbook_tv_shows_news_ginny_and_georgia_season_netflix_renewed_streaming_
# (0.9329681396484375, 'com/news/arms_build_up_as_georgia_prepares_war_on_abkhazia_south_ossetia')
# (0.9251657724380493, 'films_shot_at_pinewood_atlanta_studios')
# (0.9227016568183899, '_randy_jackson_from_american_idol_and_tareq___michaele_salahi_')
# (0.9213494658470154, '/to_catch_a_predator_is_nbcs_primetime_dragnet_the_new_american_witch_hunt/')
# (0.919877827167511, '_lb_meat_beef_modified_in_fat_content_with_tomato_and_or_catsup_on_bun')
# (0.9150041341781616, 'biz/the_late_show_with_jason_mccrossan/tribute_to')
# (0.9148027300834656, 'com/news/kosovo_recognized_by_northern_cyprus_no_people_can_be_forced_to_live_under_the_rule_of_another')
# (0.9145708084106445, '/press_release/serengeti_selects_a_new_ambassador_from_desperate_housewives_')
# (0.9125010371208191, 'book_publishing_companies_based_in_seattle,_washington')
# (0.9112151861190796, '/the_lion_in_winter_george_steinbrenner')
# ===============================================
# yahoo /quote/DOGE-USD
# yahoo_quote_DOGE_USD_
# (0.789087176322937, '_quotes')
# (0.7888986468315125, 'no_quotes')
# (0.734409749507904, 'famousquotesfunnyquotes')
# (0.7343913316726685, 'com/quotations/topic/halloween_quotes/halloween_quotes')
# (0.7303864359855652, 'kern_quotes')
# (0.7298082709312439, 'com/quotations/topic/christmas_quotes/christmas_quotes')
# (0.7263025045394897, 'com/quotes/halloween_quotes/')
# (0.7254194617271423, 'com/quotes/labor_day_quotes/')
# (0.722521185874939, 'com/nisargadatta_maharaj_quotes')
# (0.7173283696174622, 'com/support/customscripts/environmentvariablereference')
# ===============================================
# yahoo
# yahoo_
# (0.7351774573326111, 'yahoofs')
# (0.6723772883415222, 'yahoot')
# (0.6662530303001404, 'yahoo/google')
# (0.6523705720901489, 'yahooey')
# (0.6505153179168701, 'yahoo')
# (0.6485353112220764, 'yahoo\\')
# (0.6436032652854919, 'yahoo%')
# (0.6403785943984985, 'yahoocojp')
# (0.6262702941894531, 'se/group/oasis+stopcryingyourheartout')
# (0.6255614161491394, 'com/user/younusharami')
# ===============================================
# yahoo
# yahoo_
# (0.7351774573326111, 'yahoofs')
# (0.6723772883415222, 'yahoot')
# (0.6662530303001404, 'yahoo/google')
# (0.6523705720901489, 'yahooey')
# (0.6505153179168701, 'yahoo')
# (0.6485353112220764, 'yahoo\\')
# (0.6436032652854919, 'yahoo%')
# (0.6403785943984985, 'yahoocojp')
# (0.6262702941894531, 'se/group/oasis+stopcryingyourheartout')
# (0.6255614161491394, 'com/user/younusharami')
# ===============================================
# yahoo
# yahoo_
# (0.7351774573326111, 'yahoofs')
# (0.6723772883415222, 'yahoot')
# (0.6662530303001404, 'yahoo/google')
# (0.6523705720901489, 'yahooey')
# (0.6505153179168701, 'yahoo')
# (0.6485353112220764, 'yahoo\\')
# (0.6436032652854919, 'yahoo%')
# (0.6403785943984985, 'yahoocojp')
# (0.6262702941894531, 'se/group/oasis+stopcryingyourheartout')
# (0.6255614161491394, 'com/user/younusharami')
# ===============================================
# blackpeoplemeet /v3/profile
# blackpeoplemeet_v_profile_
# (0.8450345993041992, 'jan/company_profile_')
# (0.8349416255950928, 'jcw_profile_ianbloody')
# (0.799032986164093, 'ray_profiles_explained/')
# (0.7982743382453918, '/bpmj_stds_survey_koleelee')
# (0.7899701595306396, '/latest_iphone_software_supports_full_screen_web_apps')
# (0.7876026034355164, 'com/internet_brands_buys_two_web_sites__looks_to_future_acquisitions/s')
# (0.7852919101715088, 'uk/uni_profile')
# (0.7842268347740173, 'latest_property_pictures')
# (0.7801268696784973, 'za/divisions_telecom_satellite_iridium_products_page_handset')
# (0.778782069683075, 'com/fishbowldc/television/oreilly_im_mad_as_hell_and_im_not_acting_')
# ===============================================
# weather /weather/hourbyhour/l/c44f2773cda02fec98442b446569b1a196b72bcb73ca2acdcf864db6e4c2fc18
# weather_weather_hourbyhour_l_c_f_cda_fec_b_b_a_b_bcb_ca_acdcf_db_e_c_fc_
# (0.9060473442077637, 'com/index_home_acura_audi_bmw_cadillac_chevrolet_dodge_ford_gmc_honda_infiniti_lexus_mercedes_mitsubishi_nissan_toyota_vw_body_kits_ground_effects')
# (0.8995914459228516, '_visitors_flock_to_urbis_as_revamp_pays_off')
# (0.898756206035614, '_automotive_truck_van_and_suv_oem_replacement_spark_plug_pack_of_')
# (0.8984141945838928, 'com/news/coverstory/amy_winehouse_back_in_black_rehab_married_soul_beehive_diva')
# (0.8976262807846069, '/rebecca_loos_new_single_what_happens_after_a_celebrity_sex_scandal/')
# (0.8948292136192322, '_clumsy_blond_woman_trying_to_climb_a_ladder_in_heels_falling_over')
# (0.8930723071098328, 'de_singapore_flyer_beats_london_eye')
# (0.8918976783752441, 'com/talks/srikumar_rao_plug_into_your_hard_wired_happiness')
# (0.891829252243042, '/tctd/aotw/animal_collective_merriweather_post_pavillion_too_rapidshare_or_not_too_rap/')
# (0.8911729454994202, 'interpretive_work,_newfoundland_rangers_monthly_reports,_port_hope_simpson,_analysis_and_interpretation_')
# ===============================================
